# %%
import os, numpy as np, histogram.hdf as hh, histogram as H
from matplotlib import pyplot as plt
# %matplotlib notebook

# %%
here = os.path.abspath('.')

# %%
datadir = os.path.join(here, '..', 'tests', 'data', 'graphite')
doshist = hh.load(os.path.join(datadir, 'exp_DOS.h5'))

# %% [markdown]
# Takes one hour

# %%
from mcvine.phonon.powderSQE import use_phonopy
IQEhist = use_phonopy.from_FORCE_CONSTANTS(
    datadir,
    Ei = 300., # meV                                                                                                                                                                                                                                         
    T=300., # kelvin                                                                                                                                                                                                                                         
    doshist = doshist, # DOS histogram                                                                                                                                                                                                                       
    mass = 12, # hack                                                                                                                                                                                                                                        
    species = ['C'], supercell = (6,6,1),
    Q_bins = np.arange(0, 23, 0.1), E_bins = np.arange(0, 250, 1),
    workdir = '_tmp.powderSQE', N=int(1e7), include_multiphonon=True
)
# Out:
# Running phonopy...  Done
# 100%|██████████| 12/12 [01:49<00:00,  8.74s/it]

# %%
H.plot(IQEhist, min=0, max=2e-3)
# Out:
# plot z in (0, 0.002)
# <img src="data:image/png;base64,..." width="640">
