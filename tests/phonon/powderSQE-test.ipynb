# %%
import numpy as np, os
import matplotlib as mpl
# %matplotlib notebook

# %%
import histogram as H

# %%
datadir = '/SNS/users/linjiao/simulations/samples/Al/phonons-grid100/'

# %%
cd ~/dv/mcvine/phonon/tests/phonon/
# Out:
# /home/lj7/dv/mcvine/phonon/tests/phonon

# %%
from mcvine.phonon.powderSQE import from_phonon_data_dir

# %%
# %%time
IQEhist = from_phonon_data_dir(datadir, max_hkl=10)
# Out:
# /home/lj7/dv/mcvine/export/lib/python2.7/site-packages/mcvine/phonon/powderSQE.py:30: RuntimeWarning: invalid value encountered in sqrt
#   omega = omega2**.5 * units.hertz2mev
# > /home/lj7/dv/mcvine/export/lib/python2.7/site-packages/mcvine/phonon/powderSQE.py(84)compute()
# -> bins = Q_bins, E_bins
# (Pdb) c
# [-10 -10 -10] skipped
# [-10 -10  -9] skipped
# [-10 -10  -8] skipped
# [-10 -10  -7] skipped
# [-10 -10  -6] skipped
# [-10 -10  -5] skipped
# [-10 -10  -4] skipped
# [-10 -10  -3] skipped
# [-10 -10  -2] skipped
# [-10 -10  -1] skipped
# [-10 -10   0] skipped
# [-10 -10   1] skipped
# [-10 -10   2] skipped
# [-10 -10   3] skipped
# [-10 -10   4] skipped
# [-10 -10   5] skipped
# [-10 -10   6] skipped
# [-10 -10   7] skipped
# [-10 -10   8] skipped
# [-10 -10   9] skipped
# [-10 -10  10] skipped
# [-10  -9 -10] skipped
# [-10  -9  -9] skipped
# [-10  -9  -8] skipped
# [-10  -9  -7] skipped
# [-10  -9  -6] skipped
# [-10  -9  -5] skipped
# [-10  -9  -4] skipped
# ...

# %%
H.plot(IQEhist, min=0, max=1e7)
# Out:
# plot z in (0, 10000000.0)
# <img src="data:image/png;base64,..." width="640">
