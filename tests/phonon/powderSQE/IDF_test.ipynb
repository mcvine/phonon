# %%
import numpy as np, os
import matplotlib as mpl
# %matplotlib notebook

# %%
import histogram as H

# %%
datadir = '/SNS/users/linjiao/simulations/samples/Al/phonons-grid100/'

# %%
ls {datadir}
# Out:
# Al.xyz  dos.h5           make-system.py~  Polarizations  Qgridinfo  WeightedQ
# DOS     make-system.py*  Omega2           POSCAR         system

# %%
cd ~/dv/mcvine/phonon/tests/phonon/powderSQE/
# Out:
# /home/lj7/dv/mcvine/phonon/tests/phonon/powderSQE

# %%
from mcvine.phonon.powderSQE.IDF import from_data_dir

# %%
# %%time
IQEhist = from_data_dir(datadir, max_hkl=10)
# Out:
# /home/lj7/dv/mcvine/export/lib/python2.7/site-packages/mcvine/phonon/powderSQE/IDF.py:52: RuntimeWarning: invalid value encountered in sqrt
#   omega = omega2**.5 * units.hertz2mev
# [-6 -4 -4]
# /home/lj7/miniconda2/envs/dev-mcvine/lib/python2.7/site-packages/numpy/lib/function_base.py:973: RuntimeWarning: invalid value encountered in greater_equal
#   not_smaller_than_edge = (sample[:, i] >= edges[i][-1])
# [-6 -4 -3]
# [-6 -4 -2]
# [-6 -3 -4]
# [-6 -3 -3]
# [-6 -3 -2]
# [-6 -2 -4]
# [-6 -2 -3]
# [-6 -2 -2]
# [-5 -5 -5]
# [-5 -5 -4]
# [-5 -5 -3]
# [-5 -5 -2]
# [-5 -4 -5]
# [-5 -4 -4]
# [-5 -4 -3]
# [-5 -4 -2]
# [-5 -4 -1]
# [-5 -3 -5]
# [-5 -3 -4]
# [-5 -3 -3]
# [-5 -3 -2]
# [-5 -3 -1]
# [-5 -3  0]
# [-5 -2 -5]
# [-5 -2 -4]
# [-5 -2 -3]
# [-5 -2 -2]
# [-5 -2 -1]
# [-5 -2  0]
# [-5 -1 -4]
# [-5 -1 -3]
# [-5 -1 -2]
# [-5 -1 -1]
# [-5 -1  0]
# [-5  0 -3]
# [-5  0 -2]
# [-5  0 -1]
# [-5  0  0]
# [-4 -6 -4]
# [-4 -6 -3]
# [-4 -6 -2]
# [-4 -5 -5]
# [-4 -5 -4]
# [-4 -5 -3]
# [-4 -5 -2]
# ...

# %%
H.plot(IQEhist, min=0, max=1e7)
# Out:
# plot z in (0, 10000000.0)
# <img src="data:image/png;base64,..." width="640">
